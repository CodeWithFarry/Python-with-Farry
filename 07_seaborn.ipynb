# %% [markdown]
# # Seaborn Library

# %% [markdown]
# ## Distribution Plots
# 1) distplot
# 2) joinplot
# 3) pairplot

# %%
import seaborn as sns

# %%
df= sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
import pandas as pd

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np

# %%
df.replace('No', np.nan, inplace=True)

# %%
df.replace('Yes', np.nan, inplace=True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female    NaN  Sun  Dinner     2
# 1       10.34  1.66    Male    NaN  Sun  Dinner     3
# 2       21.01  3.50    Male    NaN  Sun  Dinner     3
# 3       23.68  3.31    Male    NaN  Sun  Dinner     2
# 4       24.59  3.61  Female    NaN  Sun  Dinner     4

# %%
x = df

# %%
y = df.drop(df[['sex','smoker', 'day', 'time']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 y = df.drop(df[['sex','smoker', 'day', 'time']])
#
# File c:\Users\qaisar\miniconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.corr()
#
# File c:\Users\qaisar\miniconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\qaisar\miniconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# # Correlation with heatmap
#
# correlation only calculated for numerical features.

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## JoinPlot

# %%
sns.jointplot(x= 'tip', y= 'total_bill', data= df, kind='hex')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue= 'sex')

# %%
sns.displot(df['tip'])

# %%
sns.displot(df['tip'], kde= True, bins= 15)

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# 1) box plot
# 2) vilion plot
# 3) countplot
# 4) bar plot

# %%
sns.countplot(df['size'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.barplot(x= 'total_bill', y= 'tip', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x='day', y='total_bill', data=df, palette='rainbow')
# Out:
# C:\Users\qaisar\AppData\Local\Temp\ipykernel_5460\1338029446.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=df, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df, orient='v')
# Out:
# <Axes: >

# %%
sns.boxplot(x='total_bill', y='day', hue= 'smoker', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x='total_bill', y = 'day', data= df, palette='rainbow')
# Out:
# C:\Users\qaisar\AppData\Local\Temp\ipykernel_5460\1915960370.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='total_bill', y = 'day', data= df, palette='rainbow')
# <Axes: xlabel='total_bill', ylabel='day'>
